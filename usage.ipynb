# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import numpy as np

# %%
# load your data here..
preds = np.random.randn(1000, 128, 128)
targets = (np.random.randn(1000, 128, 128) > 3.5).astype(int)

# %%
from pyaupro import PerRegionOverlap

# %%
pro_curve = PerRegionOverlap(thresholds=100)

# %%
pro_curve.update(torch.from_numpy(preds), torch.from_numpy(targets))

# %%
fpr_metric, pro_metric = pro_curve.compute()

# %%
import matplotlib.pyplot as plt

# %%
pro_curve.plot(score=True)
plt.show()

# %%
from pyaupro import generate_random_data

# %%
# Example usage
preds, target = generate_random_data()

# %%
plt.imshow(preds[2])
plt.show()
